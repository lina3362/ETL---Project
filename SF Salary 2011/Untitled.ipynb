# %%
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import username, password, database

from sqlalchemy import create_engine, inspect

# %%
# Create Database Connection
engine = create_engine(f"postgresql://{username}:{password}@localhost:5432/{database}")
conn = engine.connect()

# %%
# Create the inspector and connect it to the engine
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['salaries']

# %%
#Create a dataframe shows salaries
Salary = pd.read_sql("SELECT * FROM salaries ORDER BY id", conn)

Salary
# Out:
#             id       employeename  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148646  148648     Joann Anderson
# 148647  148649        Leon Walker
# 148648  148650      Roy I Tillery
# 148649  148654          Joe Lopez
#
#                                               jobtitle   basepay  overtimepay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.0            0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.0       245132
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.0       106088
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.0        56121
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134402.0         9737
# ...                                                ...       ...          ...
# ...

# %%
employee_2011 = pd.read_sql(''' SELECT EmployeeName, TotalPay, Year  
                                FROM Salaries
                                WHERE Year = '2011'
                                LIMIT 10
                                       ''', conn)
employee_2011
# Out:
#          employeename  totalpay  year
# 0      NATHANIEL FORD    567595  2011
# 1        GARY JIMENEZ    538909  2011
# 2      ALBERT PARDINI    335280  2011
# 3   CHRISTOPHER CHONG    332344  2011
# 4     PATRICK GARDNER    326373  2011
# 5      DAVID SULLIVAN    316286  2011
# 6           ALSON LEE    315981  2011
# 7       DAVID KUSHNER    307899  2011
# 8      MICHAEL MORRIS    303428  2011
# 9  JOANNE HAYES-WHITE    302378  2011

# %%
employee_2012 = pd.read_sql(''' SELECT EmployeeName, TotalPay, Year  
                                FROM Salaries
                                WHERE Year = '2012'
                                LIMIT 10
                                       ''', conn)
employee_2012
# Out:
#          employeename  totalpay  year
# 0               Qi Hu     48204  2012
# 1            Xiao Xie     23504  2012
# 2      Gary Altenberg    362845  2012
# 3        Gregory Suhr    321552  2012
# 4          Khoa Trinh    336394  2012
# 5  Joanne Hayes-White    314760  2012
# 6   Frederick Binkley    337205  2012
# 7            Amy Hart    291390  2012
# 8      Edward Reiskin    294000  2012
# 9         John Martin    293022  2012
